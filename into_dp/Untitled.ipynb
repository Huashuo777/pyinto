# %%
# %matplotlib inline  # 魔法命令，自动显示
c = numpy.arange(0,5,0.1)
b = numpy.sin(c)
plt.plot(b, c)
# 不需要 plt.show()，自动显示在单元格下方
# Out:
# UsageError: unrecognized arguments: # 魔法命令，自动显示

# %% [markdown]
# a+b

# %%
a+b
# Out:
# 8
